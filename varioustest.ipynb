# %%
from XAFSanalysis import XAFSanalysis_func as func

# %% [markdown]
# # ipwidgetsのテスト

# %%
from ipywidgets import (interact, BoundedFloatText, interactive_output, HBox, VBox, Label,
                        Text, IntSlider, Layout, Checkbox, SelectMultiple, BoundedIntText,
                        Dropdown, Button, Textarea, FloatProgress, Select, IntText)
layout_objects=Layout(width='400px', height='40px')
layout_box=Layout(justify_content='flex-start')
checkbox_profiler = Checkbox(
    value=False,
    description='PROFILER: ',
    disabled=False,
    layout=layout_objects
)
checkbox_thread_fit = Checkbox(
    value=False,
    description='THREAD_FIT: ',
    disabled=False,
    layout=layout_objects
)
checkbox_optimize_fit = Checkbox(
    value=True,
    description='OPTIMIZE_FIT: ',
    disabled=False,
    layout=layout_objects
)
inttext_thread_ft = IntText(
    value=2,
    description='THREAD_FT max_workers:',
    disabled=False,
    layout=layout_objects
)
selection_data_save = Select(
    options=['TEXT','ZIP'],
    value='ZIP',
    disable=False,
    description='SAVE:',
    layout=layout_objects
)
inttext_thread_ft.style.description_width='200px'
hbox_upper = HBox([checkbox_profiler, checkbox_thread_fit, checkbox_optimize_fit])
hbox_bottoms = HBox([inttext_thread_ft, selection_data_save])
vbox_options = VBox([hbox_upper, hbox_bottoms], layout=layout_box)
display(vbox_options)

# %%
from ipywidgets import (interact, BoundedFloatText, interactive_output, HBox, VBox, Label,
                        Text, IntSlider, Layout, Checkbox, SelectMultiple, BoundedIntText,
                        Dropdown, Button, Textarea, FloatProgress, Select, IntText, Output)
from IPython.display import display
button = Button(description="Click Me!")
output = Output()
ch_value=True
checkbox_profiler = Checkbox(
    value=ch_value,
    description='PROFILER: ',
    disabled=False,
    layout=layout_objects
)
display(button, output,checkbox_profiler)

def on_button_clicked(b):
    with output:
        print(f"Button clicked. {checkbox_profiler.value}")

button.on_click(on_button_clicked)

# %%
from collections import defaultdict
from IPython.display import HTML
import ipywidgets
from pprint import pprint
reverse_lut = defaultdict(set)
styles = set()
for export_name in dir(ipywidgets.widgets):
    export = getattr(ipywidgets.widgets, export_name)
    try:
        if issubclass(export, ipywidgets.Widget) and 'style' in export.class_trait_names():
            reverse_lut[export.style.klass.__name__].add(export.__name__)
            styles.add(export.style.klass)
    except TypeError:
        pass

html = '<ul>'
for style, widgets in reverse_lut.items():
    html = f"{html}\n<li><b>{style}:</b> {', '.join(sorted(widgets))}</li>"
html += "</ul>"
HTML(html)

# %%
try:
    import piplite
    await piplite.install(['ipywidgets'])
except ImportError:
    pass
import ipywidgets as widgets
a = widgets.IntSlider(description='a')
b = widgets.IntSlider(description='b')
c = widgets.IntSlider(description='c')
def f(a, b, c):
    print('{}*{}*{}={}'.format(a, b, c, a*b*c))

out = widgets.interactive_output(f, {'a': a, 'b': b, 'c': c})

widgets.HBox([widgets.VBox([a, b, c]), out])

# %%
def work():
    time.sleep(0.2)
    return 1/filenumber

def run(progressbar):
    i = 0
    while True:
        print(f'task{i}_start')
        i += work()
        print(f'i={i}')
        progressbar.value = i
        progressbar.description = f'{i:.0%}'

display(label_unzip_button, unzip_progressbar)

# %%
    PREFIXES = ['norm', 'chik', 'FT', 'Fit']
    savefileD = '.03/fit'
    [f'{savefileD}/{prefix}' for prefix in PREFIXES]

# %%
import logging
import datetime
log_date = datetime.datetime.now()
logging.basicConfig(filename = f'XAFSanalysis_func_{log_date.strftime("%Y%m%d%H%M")}.log', encoding='utf-8', level=logging.DEBUG)
logging.info(f'test\n{log_date.strftime("%Y%m%d%H%M")}')

# %%
a=[0]*10
print(a)
b=[i for i in range(10)]
print(b)
for i,b in enumerate(b[1:]):
    if i != 0:
        print(f'{i} is ok')
    print(f'i,b={i+1},{b}')

# %%
a = []
a.append(1)
a.append(str(a[-1])+'1')
print(a[-1])

# %%
def a():
    global g_value
    g_value = 1
    b()
def b():
    global g_value
    g_value = 2
a()
print(g_value)
# Out:
# 2

# %%
a = ["a", "b", "c"]
print(a)
a = []
print(a)

# %%
import os

# %%
i_l = ["a", "b"]
is_l = ["a_s", "b_s"]
a_s = [1 , 2, 3]
b_s = [4 , 5, 6]
for i in zip(i_l, is_l):
    print(f'{i[0]} = {i[1]}')
    eval(f'print({i[1]})')

# %%
print(f"a\\a")

# %% [markdown]
# # 関数のオーバーライド

# %%
class test():
    def __init__(self,a):
        self.a = a
    def func(self):
        print(self.a)

class override(test):
    def __init__(self, a, b):
        super().__init__(a)
        self.b = b
    
    def func(self):
        super().func()
        print(self.b)

t = test('ok')
t.func()
o = override('ok','hello')
o.func()
# Out:
# ok
# ok
# hello

# %% [markdown]
# # スレッド分割

# %%
import numpy as np
ini = 0
a_l = [1,2,3, 4,5]
a=np.array_split(np.array(a_l), 3)
print(a)
b = []
for aa in a:
   
    b.append(ini)
    ini+=len(aa)
print(b)

# %%
import concurrent.futures
import numpy as np


test_dict={}
ini_files = [i for i in range(20, 0, -1)]
print(len(ini_files))
maxworker=7
result_array = np.empty((len(ini_files), 2, 3))
split_files = np.array_split(ini_files, maxworker)
print(f'split files = {split_files}')
ini = 0
initial_values = []
for split_file in split_files:
    initial_values.append(ini)
    ini+=len(split_file)
print(initial_values)

def threading(result_array, initial_value, files):
    print(f'ini_v, files = {initial_value}, {files}')
    for i,file in enumerate(files):
        test_arr=np.random.rand(2,3)
        test_arr[0][0]=file

        result_array[initial_value+i] = test_arr
    return initial_value

i_arr=[]

# with ThreadPoolExecutor() as executor:
with ThreadPoolExecutor(max_workers=maxworker) as executor:
    futures = {executor.submit(threading,result_array, initial_value, files):(initial_value, files) for initial_value, files in zip(initial_values, split_files)}
    for i, future in enumerate(concurrent.futures.as_completed(futures)):
    #for i,future in zip(range_i, executor.map(thread_save, range_i)):
        iterator_v, iterator_f = futures[future]
        ini_v = future.result()
        print(f"thread, inivalue, iterator value, file = {i}, {ini_v}, {iterator_v}, {iterator_f}\n")
print(result_array)

# %% [markdown]
# # 関数渡し

# %%
import functools
def add(a,b,c,d):
    print(f'a,b,c,d = {a},{b},{c},{d}')
def add_pertial(ta,tc):
    return functools.partial(add,a=ta, c=tc)
def test2(func,e,f):
    print(func)
    return func(b=e,d=f)

print(test2(add_pertial(1,3),2,4))

# %%
import functools
def add(a,b,c,d):
    print(f'a,b,c,d = {a},{b},{c},{d}')
    return [a,b,c,d]
def test2(func,e,f):
    print(func)
    return func(b=e,d=f)
basetwo = functools.partial(add,a=1, c=3)
print(test2(basetwo,2,4))

# %% [markdown]
#  - partialの中ではfor文の使用法

# %%
import functools
list=[5,6,7]
def add(a,b,c,d):
    print(f'a,b,c,d = {a},{b},{c},{d}')
    return [a,b,c,d]
def test2(func,e,f):
    print(func)
    for i in e:
        print(i)
        func(b=i,d=f)
#    return func(b=e,d=f)
basetwo = functools.partial(add,a=1, c=3)
print(test2(basetwo,list,4))

# %%
import logging
import datetime
logging.basicConfig(filename='example.log', encoding='utf-8', level=logging.DEBUG)
now=datetime.datetime.now()
logging.info(f"now={now.strftime('%H%M%S')}")

# %% [markdown]
# # スレッドの処理時間

# %%
import cProfile, pstats, io
import numpy as np
from pstats import SortKey
from concurrent.futures import ThreadPoolExecutor,ProcessPoolExecutor
import concurrent.futures
from numba import jit


max_number = 10000

test_profiler=cProfile.Profile()
test_profiler.enable()
test_dict={}
#for i in range(2500):
#    test_arr=np.random.rand(320,4)
#    test_dict[f"{i}"]=test_arr
   
    #np.save(f"testbin/testbin{i}",test_arr)
    #np.savetxt(f"testtext/testtext{i}",test_arr)
#np.savez(f"testbinall",**test_dict)
a_l=["a","b","c","d","e","f","g"]

#@jit
def thread_save(i):
    test_arr=np.random.rand(320,4)
    for j in range(320):
        for k in range(4):
            test_arr[j][k]=100
    test_arr[0][0]=i
    return i

result_array = [0 for _ in range(len(a_l))]
#print(f"result array = {result_array}\n")
i_arr=[]
range_i=range(100)
#print(range_i)
# with ThreadPoolExecutor() as executor:
with ThreadPoolExecutor() as executor:
    futures = {executor.submit(thread_save,i):i for i in range(max_number)}
    for i, future in enumerate(concurrent.futures.as_completed(futures)):
        iterator_i = futures[future]
        i_arr.append([i])
print(f"finish sequence\n")
        
test_profiler.disable()
#with open("test.prof",mode="a+") as test_profile: 

    #sortkey = SortKey.CUMULATIVE
    #ps = pstats.Stats(test_profiler, stream=test_profile).sort_stats(sortkey)
    #ps.print_stats() 
    #sortkey = SortKey.TIME  
    #ps = pstats.Stats(test_profiler, stream=test_profile).sort_stats(sortkey)
    #ps.print_callers(.5, 'init')
s = io.StringIO()    
sortkey = SortKey.CUMULATIVE
ps = pstats.Stats(test_profiler, stream=s).sort_stats(sortkey)
ps.print_stats(20) 
sortkey = SortKey.TIME  
ps = pstats.Stats(test_profiler, stream=s).sort_stats(sortkey)
ps.print_stats(20) 
ps.print_callers(.5)
print(s.getvalue())
# with np.load('filename.npz', allow_pickle=True) as loaded_records:
#    dimens = loaded_records['dimens']
#    matrices = loaded_records['matrices']

# %% [markdown]
# # スレッド間での変数のやり取り

# %%
import cProfile, pstats, io
import numpy as np
from pstats import SortKey
from concurrent.futures import ThreadPoolExecutor,ProcessPoolExecutor
import concurrent.futures
import time

start_time=time.time()
max_number = 10
x = 2
y = 15

a_l=np.zeros((max_number,x,y))
array_length = 3
variables = np.array([k for k in range(array_length)])
print(f'initial variables={variables}')

#@jit
def thread_share(i, a_l):
    global variables
    a_l[i,0,0] = i
    time.sleep(0.5)
    print(f'variables in thread{i} = {variables}')
    a_l[i,0,2:array_length+2] = variables
    variables = variables*2
    a_l[i,0,array_length+2:array_length+5] = variables
    return i

with ThreadPoolExecutor() as executor:
    futures = {executor.submit(thread_share, i, a_l):i for i in range(max_number)}
    for i, future in enumerate(concurrent.futures.as_completed(futures)):
        iterator_i = futures[future]
        a_l[iterator_i,0,1] = i
        future.result()
        print(f'i,iterator i = {i}, {iterator_i}')
np.set_printoptions(formatter={'float': '{:5.0f}'.format})      
print(f'a_l = \n{a_l}')        
print(f"finish sequence\n")

print(f'bench time = {time.time()-start_time}')
#test_profiler.disable()
#s = io.StringIO()    
#sortkey = SortKey.CUMULATIVE
#ps = pstats.Stats(test_profiler, stream=s).sort_stats(sortkey)
#ps.print_stats(20) 
#sortkey = SortKey.TIME  
#ps = pstats.Stats(test_profiler, stream=s).sort_stats(sortkey)
#ps.print_stats(20) 
#ps.print_callers(.5)
#print(s.getvalue())
#print(a_l)


       
#test_profiler.disable()
#with open("test.prof",mode="a+") as test_profile: 

    #sortkey = SortKey.CUMULATIVE
    #ps = pstats.Stats(test_profiler, stream=test_profile).sort_stats(sortkey)
    #ps.print_stats() 
    #sortkey = SortKey.TIME  
    #ps = pstats.Stats(test_profiler, stream=test_profile).sort_stats(sortkey)
    #ps.print_callers(.5, 'init')
#s = io.StringIO()    
#sortkey = SortKey.CUMULATIVE
#ps = pstats.Stats(test_profiler, stream=s).sort_stats(sortkey)
#ps.print_stats(20) 
#sortkey = SortKey.TIME  
#ps = pstats.Stats(test_profiler, stream=s).sort_stats(sortkey)
#ps.print_stats(20) 
#ps.print_callers(.5)
#print(s.getvalue())
# with np.load('filename.npz', allow_pickle=True) as loaded_records:
#    dimens = loaded_records['dimens']
#    matrices = loaded_records['matrices']

# %%
import cProfile, pstats, io
import numpy as np
from pstats import SortKey
from concurrent.futures import ThreadPoolExecutor,ProcessPoolExecutor
import concurrent.futures
import time

start_time=time.time()
max_number = 10
x = 2
y = 15
#test_profiler=cProfile.Profile()
#test_profiler.enable()
a_l=np.zeros((max_number,x,y))
array_length = 3
variables = np.array([k for k in range(array_length)])
print(variables)

#@jit
def thread_share(i, a_l, variables):
    #global variables
    a_l[i,0,0] = i
    time.sleep(0.5)
    print(variables)
    a_l[i,0,2:array_length+2] = variables
    variables = variables*2
    a_l[i,0,array_length+2:array_length+5] = variables
    return i

with ThreadPoolExecutor() as executor:
    futures = {executor.submit(thread_share, i, a_l, variables):i for i in range(max_number)}
    for i, future in enumerate(concurrent.futures.as_completed(futures)):
        iterator_i = futures[future]
        a_l[iterator_i,0,1] = i
        future.result()
        print(f'i,iterator i = {i}, {iterator_i}')
        
print(f'a_l = \n{a_l}')        
print(f"finish sequence\n")

print(f'bench time = {time.time()-start_time}')

# %% [markdown]
# # numpyの処理時間

# %%
import cProfile, pstats, io
import numpy as np
from pstats import SortKey
from concurrent.futures import ThreadPoolExecutor,ProcessPoolExecutor
import concurrent.futures
from numba import jit


max_number = 100000
x = 1
y = 15
test_profiler=cProfile.Profile()
test_profiler.enable()
test_dict={}

a_l=np.empty([max_number,x,y])


#@jit
def thread_save_sliced(i,a_l):
    n = [i*k for k in range(10)]
    for j in range(x):
             a_l[i,j,0:10] = n
    return i

def thread_save(i,a_l):
    n = [i*k for k in range(10)]
    for j in range(x):
             a_l[i][j][0] = n[0]
             a_l[i][j][1] = n[1]
             a_l[i][j][2] = n[2]
             a_l[i][j][3] = n[3]
             a_l[i][j][4] = n[4]
             a_l[i][j][5] = n[5]
             a_l[i][j][6] = n[6]
             a_l[i][j][7] = n[7]
             a_l[i][j][8] = n[8]
             a_l[i][j][9] = n[9]
    return i

result_array = [0 for _ in range(len(a_l))]
#print(f"result array = {result_array}\n")
i_arr=[]
range_i=range(100)
#print(range_i)
# with ThreadPoolExecutor() as executor:
with ThreadPoolExecutor() as executor:
    #futures = {executor.submit(thread_save,i,a_l):i for i in range(max_number)}
    futures = {executor.submit(thread_save_sliced,i,a_l):i for i in range(max_number)}
    for i, future in enumerate(concurrent.futures.as_completed(futures)):
        iterator_i = futures[future]
        i_arr.append([i])
print(f"finish sequence\n")
        
test_profiler.disable()
#with open("test.prof",mode="a+") as test_profile: 

    #sortkey = SortKey.CUMULATIVE
    #ps = pstats.Stats(test_profiler, stream=test_profile).sort_stats(sortkey)
    #ps.print_stats() 
    #sortkey = SortKey.TIME  
    #ps = pstats.Stats(test_profiler, stream=test_profile).sort_stats(sortkey)
    #ps.print_callers(.5, 'init')
s = io.StringIO()    
sortkey = SortKey.CUMULATIVE
ps = pstats.Stats(test_profiler, stream=s).sort_stats(sortkey)
ps.print_stats(20) 
sortkey = SortKey.TIME  
ps = pstats.Stats(test_profiler, stream=s).sort_stats(sortkey)
ps.print_stats(20) 
ps.print_callers(.5)
print(s.getvalue())
# with np.load('filename.npz', allow_pickle=True) as loaded_records:
#    dimens = loaded_records['dimens']
#    matrices = loaded_records['matrices']
#print(a_l)

# %% [markdown]
#            thread_save_sliced  max=10000 306913 function calls in 0.578 seconds
#                                max=100000  2839512 function calls in 4.198 seconds
#            thread_save         max=10000303222 function calls in 0.729 seconds
#                                max=100000 2842142 function calls in 4.534 seconds

# %%
import cProfile, pstats, io
import numpy as np
from pstats import SortKey
from numba import jit, njit
import time
from numba.typed import List


max_number = 3
x = 1
y = 15

#test_profiler=cProfile.Profile()
#test_profiler.enable()
#a_l=np.zeros((max_number,x,y))
#print(a_l)
a_l=np.empty([max_number,x,y])
#print(a_l)
ns = [k for k in range(10)]
n = np.array(ns)
#typed_n = List()
#[typed_n.append(n) for n in ns]
start_time=time.time()
@jit 
def save_sliced(i, a_l, n):
    n = [i*k for k in range(10)]
    for j in range(x):
             a_l[i,j,0:10] = n
    return i
@jit
def save_index(i,a_l):
    #n = [i*k for k in range(10)]
    for j in range(x):
             a_l[i][j][0] = n[0]
             a_l[i][j][1] = n[1]
             a_l[i][j][2] = n[2]
             a_l[i][j][3] = n[3]
             a_l[i][j][4] = n[4]
             a_l[i][j][5] = n[5]
             a_l[i][j][6] = n[6]
             a_l[i][j][7] = n[7]
             a_l[i][j][8] = n[8]
             a_l[i][j][9] = n[9]
    return i
for i in range(max_number):
    save_sliced(i ,a_l, n)
    #save_index(i ,a_l )
print(f'bench time = {time.time()-start_time}')
#test_profiler.disable()
#s = io.StringIO()    
#sortkey = SortKey.CUMULATIVE
#ps = pstats.Stats(test_profiler, stream=s).sort_stats(sortkey)
#ps.print_stats(20) 
#sortkey = SortKey.TIME  
#ps = pstats.Stats(test_profiler, stream=s).sort_stats(sortkey)
#ps.print_stats(20) 
#ps.print_callers(.5)
#print(s.getvalue())
#print(a_l)

# %% [markdown]
# - save_sliced
#     - max_number = 1000000:  1.101914405822754
#         - @jit:  3.19773530960083
#         - cprofile: 3.55
#         - cprofile,@jit: 2.5
# - save_index
#     - max_number = 1000000:  5.5
#         - @jit: 1.2
#         - cprofile: 6.1
#         - cprofile,@jit: 2.75
# ### no array
# - save_index
#     - max_number = 1000000:  4.4
#         - @jit:
#         - cprofile:
#         - cprofile,@jit:

# %%
import cProfile, pstats, io
import numpy as np
from pstats import SortKey
from numba import jit
import time

max_number = 1000000
x = 2
y = 15
#test_profiler=cProfile.Profile()
#test_profiler.enable()
a_l=np.zeros((max_number,x,y))
#a_l=np.empty([max_number,x,y])
#print(a_l)
ns = [k for k in range(10)]
n = np.array(ns)
start_time=time.time()
#@jit
def save_sliced(i, a_l, n):
    #n = [i*k for k in range(10)]
    for j in range(x):
             a_l[i,j,0:10] = n
    return i
#@jit
def save_index(i, a_l, n):
    #n = [i*k for k in range(10)]
    for j in range(x):
             a_l[i][j][0] = n[0]
             a_l[i][j][1] = n[1]
             a_l[i][j][2] = n[2]
             a_l[i][j][3] = n[3]
             a_l[i][j][4] = n[4]
             a_l[i][j][5] = n[5]
             a_l[i][j][6] = n[6]
             a_l[i][j][7] = n[7]
             a_l[i][j][8] = n[8]
             a_l[i][j][9] = n[9]
    return i
for i in range(max_number):
    save_sliced(i ,a_l, n)
    #save_index(i, a_l, n)
print(f'bench time = {time.time()-start_time}')
#test_profiler.disable()
#s = io.StringIO()    
#sortkey = SortKey.CUMULATIVE
#ps = pstats.Stats(test_profiler, stream=s).sort_stats(sortkey)
#ps.print_stats(20) 
#sortkey = SortKey.TIME  
#ps = pstats.Stats(test_profiler, stream=s).sort_stats(sortkey)
#ps.print_stats(20) 
#ps.print_callers(.5)
#print(s.getvalue())
#print(a_l)

# %% [markdown]
# - save_index
#     - max_number = 1000000:
#         - no pass argument def save_index(i): 11.8
#         - pass argument def save_index(i, a_l, n): 11.0
#         - @jit: 1.0
#         - cprofile: 11.3
#         - cprofile,@jit: 2.3
#
# - save_sliced
#     - max_number = 1000000:  1.7
#         - @jit:  0.9
#         - cprofile: 2.0
#         - cprofile,@jit: 2.1

# %% [markdown]
# - save_sliced
#     - max_number = 10000:     20112 function calls in 0.039 seconds
#     - max_number = 100000:    200112 function calls in 0.406 seconds
#         - @jit:     369286 function calls (351399 primitive calls) in 0.554 seconds
# - save_index
#     - max_number = 10000:      20112 function calls in 0.075 seconds
#     - max_number = 100000:    200112 function calls in 0.748 seconds
#         - @jit:      771251 function calls (728326 primitive calls) in 0.858 seconds

# %%
import cProfile, pstats, io
import numpy as np
from pstats import SortKey
from concurrent.futures import ThreadPoolExecutor,ProcessPoolExecutor
import concurrent.futures

test_profiler=cProfile.Profile()
test_profiler.enable()
test_dict={}
#for i in range(2500):
#    test_arr=np.random.rand(320,4)
#    test_dict[f"{i}"]=test_arr
   
    #np.save(f"testbin/testbin{i}",test_arr)
    #np.savetxt(f"testtext/testtext{i}",test_arr)
#np.savez(f"testbinall",**test_dict)
a_l=["a","b","c","d","e","f","g"]
def thread_save(i):
    test_arr=np.random.rand(320,4)
    test_arr[0][0]=i
    np.savetxt(f"testtext/testtext{i}",test_arr)
    return i
result_array = [0 for _ in range(len(a_l))]
print(f"result array = {result_array}\n")
i_arr=[]
range_i=range(100)
print(range_i)
# with ThreadPoolExecutor() as executor:
with ThreadPoolExecutor() as executor:
    #futures = {executor.submit(thread_save,i):i for i in range(100)}
    for i, future in enumerate(concurrent.futures.as_completed(futures)):
    #for i,future in zip(range_i, executor.map(thread_save, range_i)):
        iterator_i, iterator_d = futures[future]
        #iterator_i = futures[future]
        #future.result()
        #future.result()
        #print(f"iterator i, d, future={iterator_i}, {iterator_d}, {future}\n")
        # correct_number = a_l.index(as_comp)
        #print(f"thread, iterator i = {i}, {iterator_i}\n")
        #i_arr.append([i, iterator_i])
        i_arr.append([i])
        #returned_i,str=future.result()
        #print(f"results={future.result()}")
        #result_array[returned_i]=str
        #print(f"{i}-restult i, str={returned_i}, {str}\n")
#print(f"final results = \n{result_array}\n")
print(f"i_arr = {i_arr}\n")
print(f"finish sequence\n")
        
test_profiler.disable()
with open("test.prof",mode="a+") as test_profile: 
    sortkey = SortKey.CUMULATIVE
    ps = pstats.Stats(test_profiler, stream=test_profile).sort_stats(sortkey)
    ps.print_stats() 
    sortkey = SortKey.TIME  
    ps = pstats.Stats(test_profiler, stream=test_profile).sort_stats(sortkey)
    ps.print_callers(.5, 'init')

# with np.load('filename.npz', allow_pickle=True) as loaded_records:
#    dimens = loaded_records['dimens']
#    matrices = loaded_records['matrices']

# %%
import cProfile, pstats, io
import numpy as np
from pstats import SortKey
from concurrent.futures import ThreadPoolExecutor,ProcessPoolExecutor
import concurrent.futures
test_profiler=cProfile.Profile()
test_profiler.enable()
test_dict={}
#for i in range(2500):
#    test_arr=np.random.rand(320,4)
#    test_dict[f"{i}"]=test_arr
   
    #np.save(f"testbin/testbin{i}",test_arr)
    #np.savetxt(f"testtext/testtext{i}",test_arr)
#np.savez(f"testbinall",**test_dict)
a_l=["a","b","c","d","e","f","g"]
def thread_save(i):
    test_arr=np.random.rand(320,4)
    test_arr[0][0]=i
    np.savetxt(f"testtext/testtext{i}",test_arr)
    return i
result_array = [0 for _ in range(len(a_l))]
print(f"result array = {result_array}\n")
i_arr=[]
#with ThreadPoolExecutor() as executor:
with ProcessPoolExecutor() as executor:
    futures = {executor.submit(thread_save,i):i for i in range(100)}
    for i, future in enumerate(concurrent.futures.as_completed(futures)):
        #iterator_i, iterator_d = futures[future]
        iterator_i = futures[future]
        future.result()
        #future.result()
        #print(f"iterator i, d, future={iterator_i}, {iterator_d}, {future}\n")
        # correct_number = a_l.index(as_comp)
        #print(f"thread, iterator i = {i}, {iterator_i}\n")
        i_arr.append([i, iterator_i])
        #returned_i,str=future.result()
        #print(f"results={future.result()}")
        #result_array[returned_i]=str
        #print(f"{i}-restult i, str={returned_i}, {str}\n")
#print(f"final results = \n{result_array}\n")
print(f"i_arr = {i_arr}\n")
print(f"finish sequence\n")
        
test_profiler.disable()
with open("test.prof",mode="a+") as test_profile: 
    sortkey = SortKey.CUMULATIVE
    ps = pstats.Stats(test_profiler, stream=test_profile).sort_stats(sortkey)
    ps.print_stats() 
    sortkey = SortKey.TIME  
    ps = pstats.Stats(test_profiler, stream=test_profile).sort_stats(sortkey)
    ps.print_callers(.5, 'init')

# with np.load('filename.npz', allow_pickle=True) as loaded_records:
#    dimens = loaded_records['dimens']
#    matrices = loaded_records['matrices']

# %%
import matplotlib.pyplot as plt
import random
import os
import datetime
import psutil
import csv
import numpy as np
from concurrent.futures import ThreadPoolExecutor, ProcessPoolExecutor
import time

num_graph = 1000


range_val = 100

def loopCalc1(i):
    for j in range(range_val):
        test_arr=np.random.rand(320,4)
        test_arr[0][0]=i
        np.savetxt(f"testtext/testtext{i}",test_arr)	
        #print(f'Thread1: {i}-{j}')

if __name__ == '__main__':
    time_start = time.time()
    
    # with ProcessPoolExecutor(max_workers=4) as executor:
    with ThreadPoolExecutor(max_workers=4) as executor:
        for i in range(range_val):
            executor.submit(loopCalc1, i)
    
    time_end = time.time()
    
    print(f'{round(time_end-time_start,3)} sec')

# %%
import concurrent.futures
import urllib.request

URLS = ['http://www.foxnews.com/',
        'http://www.cnn.com/',
        'http://europe.wsj.com/',
        'http://www.bbc.co.uk/',
        'http://some-made-up-domain.com/']

# Retrieve a single page and report the URL and contents
def load_url(url, timeout):
    with urllib.request.urlopen(url, timeout=timeout) as conn:
        return conn.read()

# We can use a with statement to ensure threads are cleaned up promptly
with concurrent.futures.ThreadPoolExecutor(max_workers=5) as executor:
    # Start the load operations and mark each future with its URL
    future_to_url = {executor.submit(load_url, url, 60): url for url in URLS}
    for future in concurrent.futures.as_completed(future_to_url):
        url = future_to_url[future]
        print(f"future,url,to_url={future},{url}\n{future_to_url}\n")
        try:
            data = future.result()
        except Exception as exc:
            print('%r generated an exception: %s' % (url, exc))
        else:
            print('%r page is %d bytes' % (url, len(data)))
# Out:
# future,url,to_url=<Future at 0x2ba58509550 state=finished raised HTTPError>,http://www.bbc.co.uk/
# {<Future at 0x2ba584fb3d0 state=running>: 'http://www.foxnews.com/', <Future at 0x2ba583bdbd0 state=running>: 'http://www.cnn.com/', <Future at 0x2ba584fb950 state=running>: 'http://europe.wsj.com/', <Future at 0x2ba58509550 state=finished raised HTTPError>: 'http://www.bbc.co.uk/', <Future at 0x2ba5850a090 state=running>: 'http://some-made-up-domain.com/'}
#
# 'http://www.bbc.co.uk/' generated an exception: HTTP Error 503: Service Unavailable
# future,url,to_url=<Future at 0x2ba583bdbd0 state=finished raised HTTPError>,http://www.cnn.com/
# {<Future at 0x2ba584fb3d0 state=running>: 'http://www.foxnews.com/', <Future at 0x2ba583bdbd0 state=finished raised HTTPError>: 'http://www.cnn.com/', <Future at 0x2ba584fb950 state=running>: 'http://europe.wsj.com/', <Future at 0x2ba58509550 state=finished raised HTTPError>: 'http://www.bbc.co.uk/', <Future at 0x2ba5850a090 state=running>: 'http://some-made-up-domain.com/'}
#
# 'http://www.cnn.com/' generated an exception: HTTP Error 503: Service Unavailable
# future,url,to_url=<Future at 0x2ba584fb950 state=finished raised HTTPError>,http://europe.wsj.com/
# {<Future at 0x2ba584fb3d0 state=running>: 'http://www.foxnews.com/', <Future at 0x2ba583bdbd0 state=finished raised HTTPError>: 'http://www.cnn.com/', <Future at 0x2ba584fb950 state=finished raised HTTPError>: 'http://europe.wsj.com/', <Future at 0x2ba58509550 state=finished raised HTTPError>: 'http://www.bbc.co.uk/', <Future at 0x2ba5850a090 state=running>: 'http://some-made-up-domain.com/'}
#
# 'http://europe.wsj.com/' generated an exception: HTTP Error 503: Service Unavailable
# future,url,to_url=<Future at 0x2ba584fb3d0 state=finished raised HTTPError>,http://www.foxnews.com/
# {<Future at 0x2ba584fb3d0 state=finished raised HTTPError>: 'http://www.foxnews.com/', <Future at 0x2ba583bdbd0 state=finished raised HTTPError>: 'http://www.cnn.com/', <Future at 0x2ba584fb950 state=finished raised HTTPError>: 'http://europe.wsj.com/', <Future at 0x2ba58509550 state=finished raised HTTPError>: 'http://www.bbc.co.uk/', <Future at 0x2ba5850a090 state=running>: 'http://some-made-up-domain.com/'}
#
# 'http://www.foxnews.com/' generated an exception: HTTP Error 503: Service Unavailable
# future,url,to_url=<Future at 0x2ba5850a090 state=finished raised ConnectionResetError>,http://some-made-up-domain.com/
# {<Future at 0x2ba584fb3d0 state=finished raised HTTPError>: 'http://www.foxnews.com/', <Future at 0x2ba583bdbd0 state=finished raised HTTPError>: 'http://www.cnn.com/', <Future at 0x2ba584fb950 state=finished raised HTTPError>: 'http://europe.wsj.com/', <Future at 0x2ba58509550 state=finished raised HTTPError>: 'http://www.bbc.co.uk/', <Future at 0x2ba5850a090 state=finished raised ConnectionResetError>: 'http://some-made-up-domain.com/'}
#
# 'http://some-made-up-domain.com/' generated an exception: [WinError 10054] 既存の接続はリモート ホストに強制的に切断されました。

# %%
import threading
from concurrent.futures import (ThreadPoolExecutor, wait)


    
def Counter():
    lock = threading.Lock()
    count=0
    for _ in range(1_000_000):
        
        #with lock:
        count += 1
    print(count)
    return count


def main():
    counter = Counter()
    with ThreadPoolExecutor() as executor:
        features = [executor.submit(counter) for _ in range(3)]
    print(counter)

main()

# %% [markdown]
# # line_profiler

# %%
import line_profiler
import numpy as np

def func():
    for i in range(5):
        a = np.empty([i*100, 1000])

def test():
    func()
        
profile = line_profiler.LineProfiler()
# profile.enable_by_count()
profile.add_function(func)
# profile.disable_by_count()
profile.runcall(test)
profile.print_stats()
# Out:
# Timer unit: 1e-07 s
#
# Total time: 7.5e-05 s
# File: C:\Users\fujikawa\AppData\Local\Temp\ipykernel_13352\2634657062.py
# Function: func at line 4
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      4                                           def func():
#      5         5         34.0      6.8      4.5      for i in range(5):
#      6         5        716.0    143.2     95.5          a = np.empty([i*100, 1000])

# %%
from line_profiler import LineProfiler
import numpy as np


class Model():
  def __init__(self, count):
    a = np.arange(count) ** 2
    b = np.square(np.arange(count))


def func(count):
  a = [i**2 for i in range(count)]


def test():
  Model(int(1e6))
  func(int(1e6))


prof = LineProfiler()
prof.add_module(Model)
prof.add_function(func)
prof.runcall(test)
prof.print_stats()
# Out:
# Timer unit: 1e-07 s
#
# Total time: 0.0033517 s
# File: C:\Users\fujikawa\AppData\Local\Temp\ipykernel_13352\3615913933.py
# Function: __init__ at line 6
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      6                                             def __init__(self, count):
#      7         1      16347.0  16347.0     48.8      a = np.arange(count) ** 2
#      8         1      17170.0  17170.0     51.2      b = np.square(np.arange(count))
#
# Total time: 0.22091 s
# File: C:\Users\fujikawa\AppData\Local\Temp\ipykernel_13352\3615913933.py
# Function: func at line 11
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     11                                           def func(count):
#     12         1    2209097.0 2209097.0    100.0    a = [i**2 for i in range(count)]

# %%
import random
import threading
import time

from line_profiler import LineProfiler


def do_other_stuff(numbers):
    time.sleep(1)
    s = sum(numbers)


def do_stuff(numbers):
    my_thread = threading.Thread(target=do_other_stuff, args=[numbers])
    my_thread.start()
    my_thread.join()


thread_to_lp = {}


def wrapper_in_thread(func):
    def inner(*args, **kwargs):
        lp = thread_to_lp.setdefault(threading.current_thread(), LineProfiler())
        lp.add_function(func)
        lp.enable_by_count()
        try:
            return func(*args, **kwargs)
        finally:
            lp.disable_by_count()

    return inner


do_other_stuff = wrapper_in_thread(do_other_stuff)
do_stuff = wrapper_in_thread(do_stuff)

numbers = [random.randint(1, 100) for i in range(1000)]
do_stuff(numbers)

for lp in thread_to_lp.values():
    lp.print_stats()
# Out:
# Timer unit: 1e-07 s
#
# Total time: 1.00111 s
# File: C:\Users\fujikawa\AppData\Local\Temp\ipykernel_13352\470304049.py
# Function: do_stuff at line 13
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     13                                           def do_stuff(numbers):
#     14         1        545.0    545.0      0.0      my_thread = threading.Thread(target=do_other_stuff, args=[numbers])
#     15         1       4432.0   4432.0      0.0      my_thread.start()
#     16         1   10006171.0 10006171.0    100.0      my_thread.join()
#
# Timer unit: 1e-07 s
#
# Total time: 1.00056 s
# File: C:\Users\fujikawa\AppData\Local\Temp\ipykernel_13352\470304049.py
# Function: do_other_stuff at line 8
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      8                                           def do_other_stuff(numbers):
#      9         1   10005469.0 10005469.0    100.0      time.sleep(1)
#     10         1         86.0     86.0      0.0      s = sum(numbers)

# %%
import line_profiler

# %% [markdown]
# # 変数スコープ

# %%
a = 1
def funca():
    a = 3
    print(a)

def funcb():
    global a
    b = 5
    b = a
    print(b)

funca()
funcb()
# Out:
# 3
# 1

# %% [markdown]
# # logging　低度

# %%
import logging
logging.basicConfig(filename = f'test.log', encoding='utf-8', level=logging.DEBUG)
print('logging start')
logging.info('info')
logging.debug('debug')

# %%
# Out:
# True
